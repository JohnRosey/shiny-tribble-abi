# %%
import pandas as pd
df = pd.read_excel('data.xlsx',sheet_name=1)
print("Affichage de la la feuille 2 et de son contenu")
df
# Out:
# Affichage de la la feuille 2 et de son contenu
#        detection_id  reader_uwb_id  tag_id  tag_temperature  distance  \
# 0            745502          16689   54319               25      2.06
# 1            745503          16689   54319               25      2.11
# 2            745504          16689   54319               25      2.04
# 3            745505          16689   54319               26      2.04
# 4            745506          16689   54319               26      2.01
# ...             ...            ...     ...              ...       ...
# 17525        822777          16689   54319               40      4.22
# 17526        822781          16689   54319               40      4.30
# 17527        822785          16689   54319               40      4.23
# 17528        822789          16689   54319               40      4.21
# 17529        822793          16689   54319               40      4.24
#
#        tag_motion         insert_timestamp
# 0               0  2022-06-16 11:47:46.703
# 1               0  2022-06-16 11:47:46.750
# 2               0  2022-06-16 11:47:46.813
# 3               0  2022-06-16 11:47:47.673
# 4               0  2022-06-16 11:47:52.673
# ...           ...                      ...
# 17525           0  2022-06-17 12:22:10.540
# 17526           0  2022-06-17 12:22:15.557
# 17527           0  2022-06-17 12:22:20.587
# 17528           0  2022-06-17 12:22:25.620
# 17529           0  2022-06-17 12:22:30.633
#
# [17530 rows x 7 columns]

# %% [markdown]
# Creation d'un graphique en fonction de temps et de la distance

# %%
df.plot(x='insert_timestamp', y='distance')
# Out:
# <AxesSubplot:xlabel='insert_timestamp'>
