# %%
import pandas as pd
df = pd.read_excel('data.xlsx',sheet_name=1) 

print("Affichage de la la feuille 2 et de son contenu")

df

#df.describe()

df.describe(include='all')
# Out:
# Affichage de la la feuille 2 et de son contenu
#          detection_id  reader_uwb_id   tag_id  tag_temperature      distance  \
# count    17530.000000        17530.0  17530.0     17530.000000  17530.000000
# unique            NaN            NaN      NaN              NaN           NaN
# top               NaN            NaN      NaN              NaN           NaN
# freq              NaN            NaN      NaN              NaN           NaN
# mean    784160.449059        16689.0  54319.0        40.657844      4.523812
# std      24424.634118            0.0      0.0         3.002345      2.016518
# min     745502.000000        16689.0  54319.0        25.000000      1.100000
# 25%     761704.250000        16689.0  54319.0        39.000000      2.370000
# 50%     787857.500000        16689.0  54319.0        40.000000      4.470000
# 75%     805392.000000        16689.0  54319.0        42.000000      4.670000
# max     822793.000000        16689.0  54319.0        49.000000      8.970000
# ...

# %% [markdown]
# Creation d'un graphique en fonction de temps et de la distance

# %%
df.plot.line(x='insert_timestamp', y='distance')
# Out:
# <AxesSubplot:xlabel='insert_timestamp'>

# %%
df.plot.line(x='insert_timestamp', y='distance',figsize=(24,15), linewidth= 3,marker ='o',markerfacecolor='green',markersize =12)

# %% [markdown]
# AFFICHE LES VALEURS DE LA COLONE INSERT_TIMESTAMP

# %%
df['insert_timestamp']
df['insert_timestamp'][1]
SUPERIEUR_DATE ='2022-06-16 11:47:46.750'
for x in df['insert_timestamp']:
    if df['insert_timestamp'][x] == SUPERIEUR_DATE :
        print("yes")
#check this stackoverflow stack:https://stackoverflow.com/questions/19189488/use-a-loop-to-plot-n-charts-python
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /workspace/shiny-tribble-abi/py.ipynb Cell 6' in <cell line: 4>()
#       <a href='vscode-notebook-cell://johnrosey-shinytribblea-f45d3huinuf.ws-us49.gitpod.io/workspace/shiny-tribble-abi/py.ipynb#ch0000004vscode-remote?line=2'>3</a> SUPERIEUR_DATE ='2022-06-16 11:47:46.750'
#       <a href='vscode-notebook-cell://johnrosey-shinytribblea-f45d3huinuf.ws-us49.gitpod.io/workspace/shiny-tribble-abi/py.ipynb#ch0000004vscode-remote?line=3'>4</a> for x in df['insert_timestamp']:
# ----> <a href='vscode-notebook-cell://johnrosey-shinytribblea-f45d3huinuf.ws-us49.gitpod.io/workspace/shiny-tribble-abi/py.ipynb#ch0000004vscode-remote?line=4'>5</a>     if df['insert_timestamp'][x] == SUPERIEUR_DATE :
# ...
